# %%
import pandas as pd
import numpy as np
import os
import glob
import datetime

# %%
storage= "d:\\Research\\analyze_birdnet\\" #source folder
sound_data= storage+ "sound_data\\" #location of sound files
common_resources= storage#+ "common_resources\\" #refer to common resources folder in github
dir= common_resources+ "store_birdnet_dictionaries\\"
datasheet_per_date_birdnet_only= storage + "folder_for_5mins_0.3confidence\\code\\datasheet_per_date_birdnet_only\\"

# %%
os.chdir(datasheet_per_date_birdnet_only)
df_data= pd.read_csv("5mintask_merged_datasheet.csv")
os.chdir(common_resources)
df_datasheet= pd.read_excel("current_training_dataset.xlsx")
# Out:
#        Unnamed: 0                 common name  time code      date
# 0               0  indian paradise flycatcher          0  20230309
# 1               1        red whiskered bulbul          0  20230309
# 2               2                  black kite          0  20230309
# 3               3    tickells blue flycatcher          0  20230309
# 4               4                black drongo          0  20230309
# ...           ...                         ...        ...       ...
# 92041          11                  asian koel         50  20240523
# 92042           0        white cheeked barbet         55  20240523
# 92043           1           large billed crow         55  20240523
# 92044           2           common tailorbird         55  20240523
# 92045           3    pale billed flowerpecker         55  20240523
#
# [92046 rows x 4 columns]

# %%
# date_df= df_datasheet.groupby("date").get_group(date)
# time_date_df= date_df.groupby("time code").get_group(time_code)
int(str(df_datasheet["Time"][50])[3:5])%5 *60
# Out:
# 240

# %%
def add_required_start_time_codes(df_datasheet):
    start_time_array= []
    for entry in range(len(df_datasheet["Time"])):
        variable= df_datasheet["Time"][entry]
        # print(type(df_datasheet["Time"][entry]), isinstance(variable, datetime.time))
        
        if isinstance(variable, datetime.time):
            time_code= int(str(df_datasheet["Time"][entry])[3:5])%5
            start_time= time_code*60
            start_time_array.append(start_time)
        else:
            start_time_array.append(np.nan)
    df_datasheet["start time"]= start_time_array
    return df_datasheet

df= add_required_start_time_codes(df_datasheet)
# Out:
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# <class 'datetime.time'> True
# ...

# %%
df.groupby("start time").get_group(120)
# Out:
#       Location Weather  Temperature       Date      Time  \
# 12          B7  cloudy          NaN 2024-05-23  07:02:00
# 13          B7  cloudy          NaN 2024-05-23  07:02:00
# 14          B7  cloudy          NaN 2024-05-23  07:02:00
# 15          B7  cloudy          NaN 2024-05-23  07:02:00
# 16          B7  cloudy          NaN 2024-05-23  07:02:00
# ...        ...     ...          ...        ...       ...
# 25226  Jubilee  cloudy          NaN 2022-11-26  08:52:00
# 25239  Jubilee  cloudy          NaN 2022-11-26  08:57:00
# 25240  Jubilee  cloudy          NaN 2022-11-26  08:57:00
# 25241  Jubilee  cloudy          NaN 2022-11-26  08:57:00
# 25242  Jubilee  cloudy          NaN 2022-11-26  08:57:00
#
#                             Names No. of individuals seen  \
# 12       pale billed flowerpecker                       0
# 13              large billed crow                       0
# 14                    jungle myna                       0
# ...
