# %%
import pandas as pd
import os
import numpy as np
import glob

# %%
os.chdir(r"D:\\github\\man-vs-BirdNet-summer-2024-\\embeddings\\common_resources\heard_datafiles\\")
df= pd.read_csv("filt_ds.csv")
df
# Out:
#        Unnamed: 0                        name      date  time code      loc  \
# 0               0                  black kite  20240523          0       B7
# 1               1           common tailorbird  20240523          0       B7
# 2               2        white cheeked barbet  20240523          0       B7
# 3               3                 common myna  20240523          0       B7
# 4               4                 jungle myna  20240523          0       B7
# ...           ...                         ...       ...        ...      ...
# 24196       24196         black naped monarch  20221126         57  Jubilee
# 24197       24197  indian paradise flycatcher  20221126         57  Jubilee
# 24198       24198                 ashy drongo  20221126         57  Jubilee
# 24199       24199                cinerous tit  20221126         57  Jubilee
# 24200       24200                black drongo  20221126         58  Jubilee
#
#           wea datetimelabel
# ...

# %%
len(set(df["name"]))
# Out:
# 4245
