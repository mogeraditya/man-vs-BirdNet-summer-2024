# %%
import os
import glob
import pandas as pd
import numpy as np

def make_dir(new_dir): 
    if not os.path.exists(new_dir):
        os.makedirs(new_dir)
    return "made dir " + str(new_dir)

#goal is to generate a list of bird names across the whole dataset.
wd= "D:\\github\\man-vs-BirdNet-summer-2024-\\embeddings"
common_resources= wd+ "\\common_resources\\"
os.chdir(common_resources)
df= pd.read_excel("current_training_dataset.xlsx")
os.chdir(wd)
print(df)
# Out:
#       Location Weather  Temperature       Date      Time  \
# 0           B7  cloudy          NaN 2024-05-23  07:00:00
# 1           B7  cloudy          NaN 2024-05-23  07:00:00
# 2           B7  cloudy          NaN 2024-05-23  07:00:00
# 3           B7  cloudy          NaN 2024-05-23  07:00:00
# 4           B7  cloudy          NaN 2024-05-23  07:00:00
# ...        ...     ...          ...        ...       ...
# 25252  Jubilee  cloudy          NaN 2022-11-26  09:00:00
# 25253  Jubilee  cloudy          NaN 2022-11-26  09:00:00
# 25254  Jubilee  cloudy          NaN 2022-11-26  09:00:00
# 25255  Jubilee  cloudy          NaN 2022-11-26  09:00:00
# 25256  Jubilee  cloudy          NaN 2022-11-26  09:00:00
#
#                        Names No. of individuals seen No. of individuals heard  \
# 0                 black kite                       0                        1
# 1          large billed crow                       0                        0
# 2          common tailorbird                       0                        1
# 3       white cheeked barbet                       0                        2
# 4                common myna                       0                        1
# ...                      ...                     ...                      ...
# 25252            ashy drongo                       0                        1
# 25253   blythes reed warbler                       0                        1
# 25254            common myna                       0                        1
# 25255      large billed crow                       0                        2
# 25256  oriental magpie robin                       1                        0
#
#       No. of individuals seen and heard Comments Unnamed: 10 Unnamed: 11  \
# 0                                     0      NaN         NaN         NaN
# 1                                     2      NaN         NaN         NaN
# 2                                     0      NaN         NaN         NaN
# 3                                     0      NaN         NaN         NaN
# 4                                     0      NaN         NaN         NaN
# ...                                 ...      ...         ...         ...
# 25252                                 0      NaN         NaN         NaN
# 25253                                 0      NaN         NaN         NaN
# 25254                                 0      NaN         NaN         NaN
# 25255                                 0      NaN         NaN         NaN
# 25256                                 0      NaN         NaN         NaN
#
#        Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 25252          NaN          NaN          NaN          NaN          NaN
# 25253          NaN          NaN          NaN          NaN          NaN
# 25254          NaN          NaN          NaN          NaN          NaN
# 25255          NaN          NaN          NaN          NaN          NaN
# 25256          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 17
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 25252         NaN
# 25253         NaN
# 25254         NaN
# 25255         NaN
# 25256         NaN
#
# [25257 rows x 18 columns]

# %%
#goal to label with time code
from datetime import datetime
def find_difference_in_minutes(time1, time2):
    t1= datetime.strptime(str(time1), "%H:%M:%S")
    t2= datetime.strptime(str(time2), "%H:%M:%S")
    difference= t2-t1
    minutes= difference.total_seconds()/60
    return minutes
# Out:
# 23.0

# %%
import numpy as np
x= np.add(np.zeros(shape=(1024)), np.ones(shape= (1024)))

# %%
x/2
# Out:
# array([0.5, 0.5, 0.5, ..., 0.5, 0.5, 0.5])

# %%
import os
import glob
import pickle
storage= "d:\\Research\\analyze_embeddings\\" #source folder
sound_data= storage+ "sound_data\\"
os.chdir(sound_data)
glob.glob("20230309*")
# Out:
# ['20230309_075723.WAV']

# %%
wd= "D:\\github\\man-vs-BirdNet-summer-2024-\\embeddings"
common_resources= wd+ "\\common_resources\\"
dir= common_resources+ "store_embeddings_dict\\20230309\\"
os.chdir(dir)
with open('20230309_embeddings.pickle', 'rb') as f:
    x = pickle.load(f)

x
# Out:
# {0: array([0.14162818, 0.22967372, 0.11560148, ..., 0.34242772, 0.10783231,
#         0.63228387]),
#  1: array([0.04146944, 0.17306231, 0.19490483, ..., 0.62385084, 0.16038982,
#         1.12805501]),
#  2: array([0.04346023, 0.09837395, 0.12212581, ..., 0.59811649, 0.16280576,
#         1.58684126]),
#  3: array([0.03152775, 0.12020326, 0.22235033, ..., 0.51536213, 0.10492746,
#         1.3153737 ]),
#  4: array([0.01842242, 0.1183337 , 0.27486007, ..., 0.61980621, 0.13062639,
#         1.25280987]),
#  5: array([0.03829823, 0.08625363, 0.4402542 , ..., 0.84857481, 0.31564339,
#         0.95020276]),
#  6: array([0.02362954, 0.18162684, 0.34411338, ..., 0.98747282, 0.63911337,
#         1.12623115]),
#  7: array([0.09003306, 0.28956843, 0.35705455, ..., 0.68502521, 0.50840954,
#         1.06683196]),
#  8: array([0.11157309, 0.22440291, 0.68772505, ..., 0.71682539, 0.63840994,
#         0.96047717]),
#  9: array([0.14695787, 0.18263836, 0.68345308, ..., 0.65765702, 0.23797455,
#         1.04747789]),
#  10: array([0.06909717, 0.19918126, 0.37670522, ..., 0.53945857, 0.42484954,
#         0.80855578]),
#  11: array([0.15037632, 0.25139239, 0.58978861, ..., 0.57465558, 0.25455084,
#         1.14162407]),
#  12: array([0.06051714, 0.19012792, 0.39183065, ..., 0.53545807, 0.46508232,
#         1.19023858]),
#  13: array([0.04922533, 0.1742639 , 0.59773792, ..., 0.7218554 , 0.35996533,
#         1.18954282]),
#  14: array([0.10812258, 0.2339335 , 0.52731265, ..., 0.67540041, 0.44914658,
#         1.17944712]),
#  15: array([0.05862959, 0.22264021, 0.4827255 , ..., 0.61969127, 0.34034279,
#         1.13683601]),
#  16: array([0.15593229, 0.10742803, 0.49554074, ..., 0.36727308, 0.34960687,
#         1.34999834]),
#  17: array([0.08988425, 0.13117569, 0.42705884, ..., 0.47041408, 0.17147035,
#         1.11382199]),
#  18: array([0.11880911, 0.25796677, 0.6752265 , ..., 0.63259345, 0.20985228,
#         1.39564025]),
#  19: array([0.11805427, 0.26834697, 0.84391957, ..., 0.81015616, 0.35690401,
#         1.10703451]),
#  20: array([0.02161338, 0.32836975, 0.53587762, ..., 0.70336076, 0.19070519,
#         1.27390612]),
#  21: array([0.00876996, 0.21429849, 0.5523593 , ..., 0.88266028, 0.36114693,
#         1.41869119]),
#  22: array([0.01702018, 0.18304245, 0.40099962, ..., 0.89657852, 0.30995618,
#         1.47977209]),
#  23: array([0.06974529, 0.28678758, 0.48988709, ..., 0.67542343, 0.26500808,
#         1.50685104]),
#  24: array([0.10885931, 0.27137942, 0.27929751, ..., 0.7689921 , 0.48101199,
#         1.24846633]),
#  25: array([0.02875212, 0.14380969, 0.4440142 , ..., 0.7995149 , 0.44307426,
#         1.04058024]),
#  26: array([0.04090599, 0.18881738, 0.28889659, ..., 0.79462621, 0.25551534,
#         1.0689623 ]),
#  27: array([0.07676078, 0.32052411, 0.4850176 , ..., 0.46850963, 0.2344641 ,
#         1.18965875]),
#  28: array([0.08777432, 0.18243965, 0.38550552, ..., 0.59384818, 0.25438882,
#         0.84303136]),
#  29: array([0.07066456, 0.25060363, 0.293506  , ..., 0.92463369, 0.2535128 ,
#         1.15050627]),
#  30: array([0.05790746, 0.21707385, 0.23824443, ..., 0.98823723, 0.16663724,
#         1.32079548]),
#  31: array([0.06606902, 0.24861082, 0.38121406, ..., 1.05314108, 0.14342506,
#         1.27611514]),
#  32: array([0.08723085, 0.35996649, 0.11727952, ..., 0.8681056 , 0.11619625,
#         1.25385198]),
#  33: array([0.06363394, 0.26271139, 0.3184038 , ..., 0.81128423, 0.12063225,
#         1.30354433]),
#  34: array([0.12674678, 0.24636452, 0.40207329, ..., 0.76574599, 0.20601313,
#         0.982461  ]),
#  35: array([0.04364571, 0.22363298, 0.40429583, ..., 0.55686482, 0.18629454,
#         0.61358154]),
#  36: array([0.07175376, 0.22762183, 0.43055272, ..., 0.77900058, 0.18658824,
#         1.05126787]),
#  37: array([0.20820535, 0.25474073, 0.30178361, ..., 1.22141983, 0.18255134,
#         1.4066373 ]),
#  38: array([0.33872583, 0.36078263, 0.43531787, ..., 0.93983198, 0.24518671,
#         1.20882158]),
#  39: array([0.22519329, 0.17458605, 0.40076051, ..., 0.86973848, 0.35546906,
#         1.3356475 ]),
#  40: array([0.13063429, 0.29801793, 0.40886657, ..., 0.92750844, 0.16086982,
#         1.34303033]),
#  41: array([0.03673785, 0.25586743, 0.36571993, ..., 0.98656783, 0.0831393 ,
#         1.76074966]),
#  42: array([0.06503116, 0.27160476, 0.47156493, ..., 1.22667802, 0.12564808,
#         1.36563855]),
#  43: array([0.0358751 , 0.25588329, 0.46512526, ..., 0.94448249, 0.14671957,
#         1.2918147 ]),
#  44: array([0.05611805, 0.17379125, 0.39589952, ..., 0.96908458, 0.14352571,
#         1.40078877]),
#  45: array([0.05277944, 0.05811595, 0.36525214, ..., 0.97607369, 0.1495561 ,
#         0.82821809]),
#  46: array([0.04772495, 0.08910873, 0.34722765, ..., 0.97541392, 0.24097071,
#         1.17671765]),
#  47: array([0.08862017, 0.09871077, 0.26813516, ..., 1.02846372, 0.2034373 ,
#         1.33901767]),
#  48: array([0.04802076, 0.12529487, 0.52076066, ..., 1.29205774, 0.21795832,
#         0.83811705]),
#  49: array([0.13173097, 0.12074635, 0.35716662, ..., 1.01526951, 0.19781698,
#         1.07263638]),
#  50: array([0.20410181, 0.20454914, 0.17878197, ..., 1.16315931, 0.20104582,
#         1.14505484]),
#  51: array([0.14209463, 0.18604278, 0.16329533, ..., 1.32212435, 0.15826724,
#         0.87061085]),
#  52: array([0.10795324, 0.26293243, 0.28584861, ..., 0.70500786, 0.15405158,
#         1.15668036]),
#  53: array([0.08399128, 0.31441662, 0.19046136, ..., 0.74014111, 0.1839569 ,
#         1.23109684]),
#  54: array([0.02725058, 0.29201242, 0.37497213, ..., 0.89314008, 0.17325865,
#         1.00458456]),
#  55: array([0.12584526, 0.27246972, 0.45608063, ..., 1.22263742, 0.15889314,
#         1.21997537]),
#  56: array([0.12743178, 0.17266359, 0.29750974, ..., 1.17357939, 0.06643946,
#         1.03371227]),
#  57: array([0.1253406 , 0.20240712, 0.25921027, ..., 0.86540938, 0.23809081,
#         0.9550391 ]),
#  58: array([0.07279984, 0.27220614, 0.29730398, ..., 0.52453554, 0.24804062,
#         0.925909  ]),
#  59: array([0.06857829, 0.17287452, 0.3754538 , ..., 1.03666949, 0.36636522,
#         1.08969055])}
